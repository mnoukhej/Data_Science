# %%
# !which python
# Out:
# /d/Codding/Projects/ICDS/.venv/Scripts/python

# %% [markdown]
# **Import Models**

# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv("Datasets/players_22.csv")
df.head()
# Out:
# C:\Users\MUHAMMAD NOUKHEZ\AppData\Local\Temp\ipykernel_5980\1767269169.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Datasets/players_22.csv")
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# ...

# %%
df.shape
# Out:
# (19239, 110)

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=110)

# %%
df = df.drop(columns=['weak_foot', 'real_face'])
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=108)

# %%
len(df)
# Out:
# 19239

# %%
df.query("shooting > passing")
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 6         231747  https://sofifa.com/player/231747/kylian-mbappe...
# 9         202126  https://sofifa.com/player/202126/harry-kane/22...
# ...          ...                                                ...
# 19220     243725  https://sofifa.com/player/243725/darren-collin...
# 19221     243790  https://sofifa.com/player/243790/zhenao-wang/2...
# 19228     259650  https://sofifa.com/player/259650/fardin-ali-mo...
# 19232     261667  https://sofifa.com/player/261667/matthew-obrie...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
#
#               short_name                            long_name  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
df.iloc[:10, 5:10]
# Out:
#    overall  potential    value_eur  wage_eur  age
# 0       93         93   78000000.0  320000.0   34
# 1       92         92  119500000.0  270000.0   32
# 2       91         91   45000000.0  270000.0   36
# 3       91         91  129000000.0  270000.0   29
# 4       91         91  125500000.0  350000.0   30
# 5       91         93  112000000.0  130000.0   28
# 6       91         95  194000000.0  230000.0   22
# 7       90         90   13500000.0   86000.0   35
# 8       90         92   99000000.0  250000.0   29
# 9       90         90  129500000.0  240000.0   27

# %%
df.loc[[3, 10, 14, 23], ['nationality_name', 'weight_kg', "height_cm"]]
# Out:
#    nationality_name  weight_kg  height_cm
# 3            Brazil         68        175
# 10           France         70        168
# 14           Brazil         84        185
# 23          Uruguay         83        182

# %%
df.height_cm.dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# sofifa_id            int64
# player_url          object
# short_name          object
# long_name           object
# player_positions    object
#                      ...
# player_face_url     object
# club_logo_url       object
# club_flag_url       object
# nation_logo_url     object
# nation_flag_url     object
# Length: 108, dtype: object

# %%
df.select_dtypes(include='int64')
# Out:
#        sofifa_id  overall  potential  age  height_cm  weight_kg  \
# 0         158023       93         93   34        170         72
# 1         188545       92         92   32        185         81
# 2          20801       91         91   36        187         83
# 3         190871       91         91   29        175         68
# 4         192985       91         91   30        181         70
# ...          ...      ...        ...  ...        ...        ...
# 19234     261962       47         52   22        180         64
# 19235     262040       47         59   19        175         70
# 19236     262760       47         55   21        178         72
# 19237     262820       47         60   19        173         66
# 19238     264540       47         60   19        167         61
#
#        nationality_id  skill_moves  international_reputation  \
# 0                  52            4                         5
# 1                  37            4                         5
# ...

# %%
df.select_dtypes(exclude='int64')
# Out:
#                                               player_url          short_name  \
# 0      https://sofifa.com/player/158023/lionel-messi/...            L. Messi
# 1      https://sofifa.com/player/188545/robert-lewand...      R. Lewandowski
# 2      https://sofifa.com/player/20801/c-ronaldo-dos-...   Cristiano Ronaldo
# 3      https://sofifa.com/player/190871/neymar-da-sil...           Neymar Jr
# 4      https://sofifa.com/player/192985/kevin-de-bruy...        K. De Bruyne
# ...                                                  ...                 ...
# 19234  https://sofifa.com/player/261962/defu-song/220002           Song Defu
# 19235  https://sofifa.com/player/262040/caoimhin-port...           C. Porter
# 19236  https://sofifa.com/player/262760/nathan-logue/...            N. Logue
# 19237  https://sofifa.com/player/262820/luke-rudden/2...           L. Rudden
# 19238  https://sofifa.com/player/264540/emanuel-lalch...  E. Lalchhanchhuaha
#
# ...

# %%
random_col = np.random.randint(100, size=len(df))

# %%
df.insert(3, 'random_col', random_col)
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name  random_col                            long_name  \
# 0           L. Messi          23       Lionel Andrés Messi Cuccittini
# 1     R. Lewandowski          49                   Robert Lewandowski
# 2  Cristiano Ronaldo          81  Cristiano Ronaldo dos Santos Aveiro
# 3          Neymar Jr          63        Neymar da Silva Santos Júnior
# 4       K. De Bruyne          89                      Kevin De Bruyne
#
#   player_positions  overall  potential    value_eur  wage_eur  age  \
# 0       RW, ST, CF       93         93   78000000.0  320000.0   34
# ...

# %%
df[['value_eur', 'wage_eur']].cumsum()
# Out:
#           value_eur     wage_eur
# 0      7.800000e+07     320000.0
# 1      1.975000e+08     590000.0
# 2      2.425000e+08     860000.0
# 3      3.715000e+08    1130000.0
# 4      4.970000e+08    1480000.0
# ...             ...          ...
# 19234  5.462848e+10  172945000.0
# 19235  5.462859e+10  172945500.0
# 19236  5.462869e+10  172946000.0
# 19237  5.462880e+10  172946500.0
# 19238  5.462891e+10  172947000.0
#
# [19239 rows x 2 columns]

# %%
df.sample(n = 200)
# Out:
#        sofifa_id                                         player_url  \
# 9778      262436  https://sofifa.com/player/262436/adilio-correi...
# 3035      245535  https://sofifa.com/player/245535/abdulkadir-pa...
# 15720     259327  https://sofifa.com/player/259327/david-mukuna-...
# 968       212245  https://sofifa.com/player/212245/yannick-gerha...
# 6905      225652  https://sofifa.com/player/225652/george-puscas...
# ...          ...                                                ...
# 9438      241566  https://sofifa.com/player/241566/nahuel-gallar...
# 18761     259428  https://sofifa.com/player/259428/fahad-al-daws...
# 11544     233056  https://sofifa.com/player/233056/daniel-cleary...
# 7715      206106  https://sofifa.com/player/206106/cenk-sahin/22...
# 7575      189776  https://sofifa.com/player/189776/marley-watkin...
#
#              short_name  random_col                  long_name  \
# 9778      Adílio Santos          36  Adílio Correia dos Santos
# ...

# %%
df.sample(frac = 0.25)
# Out:
#        sofifa_id                                         player_url  \
# 7296      247668  https://sofifa.com/player/247668/konan-ndri/22...
# 6146      239641  https://sofifa.com/player/239641/alfa-semedo-e...
# 10066     211850  https://sofifa.com/player/211850/manfred-stark...
# 11638     238317  https://sofifa.com/player/238317/charles-rigon...
# 14096     256218    https://sofifa.com/player/256218/iba-may/220002
# ...          ...                                                ...
# 13824     242366   https://sofifa.com/player/242366/tom-sang/220002
# 16270     257714  https://sofifa.com/player/257714/sebbe-augusti...
# 1375      230425  https://sofifa.com/player/230425/rubem-thomas-...
# 12641     233375  https://sofifa.com/player/233375/darragh-leahy...
# 1285      212242  https://sofifa.com/player/212242/robert-andric...
#
#           short_name  random_col                    long_name  \
# 7296        K. N'Dri          98   Konan Ignace Jocelyn N’Dri
# ...

# %%
df['random_col'].where(df['random_col'] > 50)
# Out:
# 0         NaN
# 1         NaN
# 2        81.0
# 3        63.0
# 4        89.0
#          ...
# 19234     NaN
# 19235     NaN
# 19236     NaN
# 19237     NaN
# 19238    82.0
# Name: random_col, Length: 19239, dtype: float64

# %%
df['random_col'].where(df['random_col'] > 50, 0)
# Out:
# 0         0
# 1         0
# 2        81
# 3        63
# 4        89
#          ..
# 19234     0
# 19235     0
# 19236     0
# 19237     0
# 19238    82
# Name: random_col, Length: 19239, dtype: int32

# %%
df.skill_moves.unique()
# Out:
# array([4, 5, 1, 3, 2])

# %%
df.nationality_name.nunique()
# Out:
# 163

# %%
df.nunique()
# Out:
# sofifa_id          19239
# player_url         19239
# short_name         18145
# random_col           100
# long_name          19219
#                    ...
# player_face_url    19239
# club_logo_url        701
# club_flag_url         49
# nation_logo_url       33
# nation_flag_url      163
# Length: 109, dtype: int64

# %%
df['rank_calc'] = df["value_eur"].rank()

# %%
nationality = ["Argentina", "Portugal", "Sweden", "England"]
df[df.nationality_name.isin(nationality)]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 9         202126  https://sofifa.com/player/202126/harry-kane/22...
# 27        202652  https://sofifa.com/player/202652/raheem-sterli...
# 28        212198  https://sofifa.com/player/212198/bruno-miguel-...
# ...          ...                                                ...
# 19093     264259  https://sofifa.com/player/264259/karl-serrano-...
# 19098     264568  https://sofifa.com/player/264568/george-cowmea...
# 19099     264569  https://sofifa.com/player/264569/ricky-aguiar/...
# 19123     256427  https://sofifa.com/player/256427/mayckel-lahdo...
# 19216     263340  https://sofifa.com/player/263340/harvey-wiles-...
#
#               short_name  random_col                            long_name  \
# 0               L. Messi          23       Lionel Andrés Messi Cuccittini
# ...

# %%
df.replace(1.0, 1.1)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name  random_col                            long_name  \
# ...

# %%
df.replace({1.0: 1.1, 4.0: 4.1, 3.0: 3.1})
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name  random_col                            long_name  \
# ...

# %%
df.rename(columns = {"weight_kg": "Weight (kg)", "height_cm": "Height (cm)"})
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name  random_col                            long_name  \
# ...

# %%
df['pace'].fillna(0, inplace=True)
# Out:
# C:\Users\MUHAMMAD NOUKHEZ\AppData\Local\Temp\ipykernel_5980\4166706740.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['pace'].fillna(0, inplace=True)

# %%
df['pace'].fillna(df['pace'].mean(), inplace = True)
# Out:
# C:\Users\MUHAMMAD NOUKHEZ\AppData\Local\Temp\ipykernel_5980\2727464650.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['pace'].fillna(df['pace'].mean(), inplace = True)

# %%
df.groupby("nationality_name")['value_eur'].sum()
# Out:
# nationality_name
# Afghanistan       875000.0
# Albania        125805000.0
# Algeria        317095000.0
# Andorra           400000.0
# Angola          42875000.0
#                   ...
# Venezuela      279550000.0
# Vietnam           525000.0
# Wales          234360000.0
# Zambia          41200000.0
# Zimbabwe        36090000.0
# Name: value_eur, Length: 163, dtype: float64

# %%
# df.groupby(['nationality_name', 'league_level'])['value_eur', 'wage_eur'].agg([np.mean, np.median])

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'random_col', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        ...
#        'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url', 'rank_calc'],
#       dtype='object', length=110)

# %%
df.value_eur.pct_change()
# Out:
# C:\Users\MUHAMMAD NOUKHEZ\AppData\Local\Temp\ipykernel_5980\3206206586.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df.value_eur.pct_change()
# 0             NaN
# 1        0.532051
# 2       -0.623431
# 3        1.866667
# 4       -0.027132
#            ...
# 19234   -0.363636
# 19235    0.571429
# 19236   -0.090909
# 19237    0.100000
# 19238    0.000000
# Name: value_eur, Length: 19239, dtype: float64

# %%
df.count(0)
# Out:
# sofifa_id          19239
# player_url         19239
# short_name         19239
# random_col         19239
# long_name          19239
#                    ...
# club_logo_url      19178
# club_flag_url      19178
# nation_logo_url      759
# nation_flag_url    19239
# rank_calc          19165
# Length: 110, dtype: int64

# %%
df.count(1)
# Out:
# 0        108
# 1        108
# 2        108
# 3        104
# 4        108
#         ...
# 19234    102
# 19235    102
# 19236    102
# 19237    102
# 19238    102
# Length: 19239, dtype: int64

# %%
df['league_level'].value_counts()
# Out:
# league_level
# 1.0    14857
# 2.0     2513
# 3.0     1168
# 4.0      613
# 5.0       27
# Name: count, dtype: int64

# %%
df['league_level'].value_counts(ascending=True)
# Out:
# league_level
# 5.0       27
# 4.0      613
# 3.0     1168
# 2.0     2513
# 1.0    14857
# Name: count, dtype: int64

# %%
# pd.crosstab(df['league_rank'], df['international_reputation'])|||

# %%
# pd.crosstab(df['league_rank'], df['international_reputation'], margins = True, margins_name="Total", normalize = True)

# %%
pd.qcut(df['value_eur'], q = 5)
# Out:
# 0        (2500000.0, 194000000.0]
# 1        (2500000.0, 194000000.0]
# 2        (2500000.0, 194000000.0]
# 3        (2500000.0, 194000000.0]
# 4        (2500000.0, 194000000.0]
#                    ...
# 19234        (8999.999, 400000.0]
# 19235        (8999.999, 400000.0]
# 19236        (8999.999, 400000.0]
# 19237        (8999.999, 400000.0]
# 19238        (8999.999, 400000.0]
# Name: value_eur, Length: 19239, dtype: category
# Categories (5, interval[float64, right]): [(8999.999, 400000.0] < (400000.0, 750000.0] < (750000.0, 1300000.0] < (1300000.0, 2500000.0] < (2500000.0, 194000000.0]]

# %%
pd.qcut(df['value_eur'], q = 5).value_counts()
# Out:
# value_eur
# (750000.0, 1300000.0]       4011
# (400000.0, 750000.0]        3931
# (8999.999, 400000.0]        3930
# (2500000.0, 194000000.0]    3783
# (1300000.0, 2500000.0]      3510
# Name: count, dtype: int64

# %%
pd.cut(df['value_eur'], bins = 5).value_counts()
# Out:
# value_eur
# (-184991.0, 38807200.0]       18993
# (38807200.0, 77605400.0]        130
# (77605400.0, 116403600.0]        33
# (116403600.0, 155201800.0]        8
# (155201800.0, 194000000.0]        1
# Name: count, dtype: int64

# %%
df['wage_eur'].describe()
# Out:
# count     19178.000000
# mean       9017.989363
# std       19470.176724
# min         500.000000
# 25%        1000.000000
# 50%        3000.000000
# 75%        8000.000000
# max      350000.000000
# Name: wage_eur, dtype: float64

# %%
df.nlargest(5, "wage_eur")
# Out:
#     sofifa_id                                         player_url  \
# 4      192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 11     165153  https://sofifa.com/player/165153/karim-benzema...
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 14     200145  https://sofifa.com/player/200145/carlos-henriq...
# 24     182521  https://sofifa.com/player/182521/toni-kroos/22...
#
#       short_name  random_col                          long_name  \
# 4   K. De Bruyne          89                    Kevin De Bruyne
# 11    K. Benzema          33                      Karim Benzema
# 0       L. Messi          23     Lionel Andrés Messi Cuccittini
# 14      Casemiro           5  Carlos Henrique Venancio Casimiro
# 24      T. Kroos          50                         Toni Kroos
#
#    player_positions  overall  potential    value_eur  wage_eur  age  \
# 4           CM, CAM       91         91  125500000.0  350000.0   30
# ...

# %%
df.nsmallest(5, "wage_eur")
# Out:
#       sofifa_id                                         player_url  \
# 1450     246618  https://sofifa.com/player/246618/adam-hlozek/2...
# 1467     142902  https://sofifa.com/player/142902/andriy-pyatov...
# 2375     241769  https://sofifa.com/player/241769/daniel-akpeyi...
# 3122     177299  https://sofifa.com/player/177299/adrian-gabbar...
# 3654     234054  https://sofifa.com/player/234054/carlos-caceda...
#
#         short_name  random_col                      long_name  \
# 1450     A. Hložek          46                    Adam Hložek
# 1467     A. Pyatov          30                  Andriy Pyatov
# 2375     D. Akpeyi          58                  Daniel Akpeyi
# 3122  A. Gabbarini          82          Adrián José Gabbarini
# 3654     C. Cáceda          92  Carlos Alberto Cáceda Oyaguez
#
#      player_positions  overall  potential   value_eur  wage_eur  age  \
# 1450       ST, LM, RM       76         87  16000000.0     500.0   18
# ...

# %%
df1 = pd.DataFrame({"city": ['A', 'B', 'C'], "day1": [22, 25, 21], 'day2':[31, 12, 67], 'day3': [27, 20, 15], 'day4': [34, 37, [41, 45, 67, 90, 21]], 'day5': [23, 54, 36]})

# %%
df1
# Out:
#   city  day1  day2  day3                  day4  day5
# 0    A    22    31    27                    34    23
# 1    B    25    12    20                    37    54
# 2    C    21    67    15  [41, 45, 67, 90, 21]    36

# %%
# df1.explode(jupyter notebook 'day4').reset_index(drop=True)
